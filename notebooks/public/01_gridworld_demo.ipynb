# %% [markdown]
# # Gridworld Demo
#
# Lightweight public demo of the attacker-defender gridworld.

# %%
from pathlib import Path
import sys

root = Path.cwd().resolve().parent.parent
src = root / "src"
sys.path.insert(0, str(src))

from strategy_games.envs.gridworld import AttackerDefenderGridworld

env = AttackerDefenderGridworld()
obs = env.reset()
print(obs)
print(env.render())
# Out:
# [0.  0.  1.  1.  1.  0.  0.  0.5 1. ]
# A . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# G . . . . . . . . D

# %%
root
# Out:
# PosixPath('/Users/cyrusmoazami/Research_projects/Energy-based-models-reasoning/energy-strategy-games')
